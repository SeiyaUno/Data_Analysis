# %% [markdown]
# ## In Vehicle Coupon Recommendation
#
# source
# https://archive.ics.uci.edu/dataset/603/in+vehicle+coupon+recommendation
#
# check page 22
# https://jmlr.org/papers/volume18/16-003/16-003.pdf
#
# Y column indicates whether the person accepts coupon or not,
# Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.

# %%
import pandas as pd
from plotnine import *

# %%
df = pd.read_csv("./in-vehicle-coupon-recommendation.csv")

# %%
df.sample(3)
# Out:
#            destination  passanger weather  temperature time  \
# 2623              Work      Alone   Sunny           80  7AM
# 7219   No Urgent Place     Kid(s)   Snowy           30  6PM
# 12287  No Urgent Place  Friend(s)   Snowy           30  2PM
#
#                       coupon expiration  gender     age      maritalStatus  \
# 2623   Carry out & Take away         2h  Female      41    Married partner
# 7219                     Bar         1d    Male      36  Unmarried partner
# 12287        Restaurant(<20)         1d  Female  50plus            Widowed
#
#        ...  CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 2623   ...          1~3       1~3                  1~3            less1
# 7219   ...        never       1~3                less1            never
# 12287  ...        never       4~8                  1~3              NaN
#
#       toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 2623                 1                 0                 0              1
# 7219                 1                 1                 0              0
# 12287                1                 0                 0              0
#
#       direction_opp  Y
# 2623              0  1
# 7219              1  0
# 12287             1  1
#
# [3 rows x 26 columns]
